# %% [markdown]
# <a href="https://colab.research.google.com/github/Prab999/CSCI167/blob/main/Notebook8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-c63ryvuu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-c63ryvuu
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=29e9d154143e81db64b907ac22602d5a3d5a43c7033271148db2fef7b3acab80
#   Stored in directory: /tmp/pip-ephem-wheel-cache-60t3x5ul/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?  **Ans:** I would say it hits zero at 350 hidden vars.
# 2.   At what capacity do you expect the first minima of the double descent curve to appear? **Ans:** Maybe a good amount before that maybe at 200 hidden vars.
# 3. At what capacity do you expect the maximum of the double descent curve to appear? **Ans:** This should be at or slightly above where the training error first becomes zero so 400 hidden vars.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!
#2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400
hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.286432, train error 84.93,  test loss 2.283921, test error 84.68
# Epoch   100, train loss 1.849499, train error 70.18,  test loss 1.697596, test error 67.55
# Epoch   200, train loss 1.845987, train error 69.93,  test loss 1.699552, test error 67.90
# Epoch   300, train loss 1.844136, train error 69.95,  test loss 1.705395, test error 68.15
# Epoch   400, train loss 1.846323, train error 69.88,  test loss 1.709627, test error 67.97
# Epoch   500, train loss 1.843781, train error 70.38,  test loss 1.708113, test error 68.00
# Epoch   600, train loss 1.844444, train error 69.97,  test loss 1.717953, test error 67.85
# Epoch   700, train loss 1.843114, train error 69.82,  test loss 1.705573, test error 67.50
# Epoch   800, train loss 1.843268, train error 69.95,  test loss 1.703115, test error 68.15
# Epoch   900, train loss 1.842057, train error 69.88,  test loss 1.705989, test error 67.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.305023, train error 89.00,  test loss 2.302014, test error 88.55
# Epoch   100, train loss 1.849234, train error 69.62,  test loss 1.700982, test error 69.05
# Epoch   200, train loss 1.837888, train error 68.60,  test loss 1.712060, test error 68.78
# Epoch   300, train loss 1.827389, train error 68.90,  test loss 1.709822, test error 68.30
# Epoch   400, train loss 1.821743, train error 69.00,  test loss 1.709354, test error 67.78
# Epoch   500, train loss 1.820257, train error 68.62,  test loss 1.712460, test error 68.45
# Epoch   600, train loss 1.813333, train error 68.10,  test loss 1.704619, test error 67.43
# Epoch   700, train loss 1.812218, train error 68.05,  test loss 1.705637, test error 67.88
# Epoch   800, train loss 1.805645, train error 68.28,  test loss 1.687713, test error 67.38
# Epoch   900, train loss 1.802105, train error 67.82,  test loss 1.695591, test error 66.93
# Training model with   6 hidden variables
# Epoch     0, train loss 2.292863, train error 87.95,  test loss 2.291681, test error 87.65
# Epoch   100, train loss 1.633157, train error 56.75,  test loss 1.446521, test error 54.12
# Epoch   200, train loss 1.594908, train error 55.05,  test loss 1.416674, test error 52.38
# Epoch   300, train loss 1.572845, train error 53.62,  test loss 1.402108, test error 52.08
# Epoch   400, train loss 1.571749, train error 54.60,  test loss 1.414887, test error 52.60
# Epoch   500, train loss 1.557339, train error 53.58,  test loss 1.402098, test error 52.38
# Epoch   600, train loss 1.555114, train error 53.60,  test loss 1.395678, test error 51.55
# Epoch   700, train loss 1.552675, train error 53.75,  test loss 1.401591, test error 51.22
# Epoch   800, train loss 1.548740, train error 53.03,  test loss 1.385629, test error 51.53
# Epoch   900, train loss 1.547463, train error 53.40,  test loss 1.391713, test error 51.22
# Training model with   8 hidden variables
# Epoch     0, train loss 2.292797, train error 86.05,  test loss 2.299615, test error 86.62
# Epoch   100, train loss 1.572466, train error 53.50,  test loss 1.394284, test error 51.05
# Epoch   200, train loss 1.488815, train error 50.88,  test loss 1.331355, test error 48.35
# Epoch   300, train loss 1.472105, train error 49.85,  test loss 1.317837, test error 48.08
# Epoch   400, train loss 1.466500, train error 49.70,  test loss 1.323026, test error 47.65
# Epoch   500, train loss 1.463456, train error 49.62,  test loss 1.327983, test error 47.45
# Epoch   600, train loss 1.453322, train error 49.72,  test loss 1.314255, test error 46.90
# Epoch   700, train loss 1.447869, train error 49.95,  test loss 1.310620, test error 46.83
# Epoch   800, train loss 1.439510, train error 48.88,  test loss 1.310852, test error 46.97
# Epoch   900, train loss 1.435421, train error 49.03,  test loss 1.310212, test error 47.70
# Training model with  10 hidden variables
# Epoch     0, train loss 2.274821, train error 85.00,  test loss 2.263999, test error 84.00
# Epoch   100, train loss 1.454554, train error 48.75,  test loss 1.289053, test error 47.83
# Epoch   200, train loss 1.398977, train error 47.28,  test loss 1.259635, test error 47.33
# Epoch   300, train loss 1.378979, train error 46.78,  test loss 1.277479, test error 47.88
# Epoch   400, train loss 1.377507, train error 46.78,  test loss 1.287997, test error 47.92
# Epoch   500, train loss 1.366424, train error 45.70,  test loss 1.285337, test error 47.55
# Epoch   600, train loss 1.368354, train error 46.15,  test loss 1.298596, test error 48.15
# Epoch   700, train loss 1.367730, train error 45.97,  test loss 1.308527, test error 47.92
# Epoch   800, train loss 1.365281, train error 46.45,  test loss 1.300399, test error 48.00
# Epoch   900, train loss 1.360008, train error 46.15,  test loss 1.306060, test error 48.33
# Training model with  14 hidden variables
# Epoch     0, train loss 2.250203, train error 82.80,  test loss 2.242766, test error 81.97
# Epoch   100, train loss 1.490632, train error 51.90,  test loss 1.421665, test error 54.80
# Epoch   200, train loss 1.391085, train error 48.75,  test loss 1.435278, test error 53.90
# Epoch   300, train loss 1.353436, train error 46.25,  test loss 1.453477, test error 52.85
# Epoch   400, train loss 1.339545, train error 45.70,  test loss 1.482949, test error 53.15
# Epoch   500, train loss 1.320542, train error 44.78,  test loss 1.492100, test error 53.20
# Epoch   600, train loss 1.316952, train error 45.22,  test loss 1.512617, test error 53.80
# Epoch   700, train loss 1.305129, train error 45.00,  test loss 1.527132, test error 53.92
# Epoch   800, train loss 1.296765, train error 44.33,  test loss 1.541104, test error 54.33
# Epoch   900, train loss 1.292426, train error 45.30,  test loss 1.566004, test error 54.15
# Training model with  18 hidden variables
# Epoch     0, train loss 2.094135, train error 80.15,  test loss 2.035578, test error 78.12
# Epoch   100, train loss 1.426600, train error 49.35,  test loss 1.432045, test error 54.38
# Epoch   200, train loss 1.294442, train error 44.25,  test loss 1.408695, test error 51.33
# Epoch   300, train loss 1.252593, train error 42.17,  test loss 1.431138, test error 50.58
# Epoch   400, train loss 1.213525, train error 41.22,  test loss 1.460878, test error 52.25
# Epoch   500, train loss 1.197374, train error 40.17,  test loss 1.481252, test error 51.65
# Epoch   600, train loss 1.187471, train error 39.90,  test loss 1.508849, test error 51.45
# Epoch   700, train loss 1.168058, train error 39.70,  test loss 1.524020, test error 51.47
# Epoch   800, train loss 1.164415, train error 40.10,  test loss 1.557815, test error 52.65
# Epoch   900, train loss 1.148901, train error 39.50,  test loss 1.596254, test error 53.47
# Training model with  22 hidden variables
# Epoch     0, train loss 2.209867, train error 82.12,  test loss 2.198429, test error 81.88
# Epoch   100, train loss 1.247002, train error 42.10,  test loss 1.311948, test error 49.55
# Epoch   200, train loss 1.133532, train error 36.85,  test loss 1.356928, test error 49.47
# Epoch   300, train loss 1.083221, train error 35.28,  test loss 1.442987, test error 50.78
# Epoch   400, train loss 1.053882, train error 34.82,  test loss 1.493130, test error 51.80
# Epoch   500, train loss 1.023980, train error 33.72,  test loss 1.526591, test error 51.72
# Epoch   600, train loss 1.019991, train error 33.47,  test loss 1.578203, test error 52.45
# Epoch   700, train loss 1.001841, train error 33.47,  test loss 1.626293, test error 52.60
# Epoch   800, train loss 0.993414, train error 33.20,  test loss 1.656939, test error 51.33
# Epoch   900, train loss 0.996587, train error 33.97,  test loss 1.705246, test error 51.83
# Training model with  26 hidden variables
# Epoch     0, train loss 2.144236, train error 80.90,  test loss 2.103443, test error 78.90
# Epoch   100, train loss 1.198000, train error 39.08,  test loss 1.322982, test error 49.50
# Epoch   200, train loss 1.073889, train error 35.18,  test loss 1.431678, test error 50.90
# Epoch   300, train loss 1.018303, train error 34.70,  test loss 1.549565, test error 52.58
# Epoch   400, train loss 0.946007, train error 32.10,  test loss 1.660260, test error 52.38
# Epoch   500, train loss 0.897515, train error 29.93,  test loss 1.758580, test error 53.00
# Epoch   600, train loss 0.866313, train error 28.85,  test loss 1.859334, test error 53.80
# Epoch   700, train loss 0.859421, train error 29.38,  test loss 1.939885, test error 54.10
# Epoch   800, train loss 0.841657, train error 28.60,  test loss 1.967137, test error 53.70
# Epoch   900, train loss 0.829385, train error 29.18,  test loss 2.044909, test error 54.10
# Training model with  30 hidden variables
# Epoch     0, train loss 2.159785, train error 80.00,  test loss 2.118398, test error 78.10
# Epoch   100, train loss 1.089347, train error 35.90,  test loss 1.341270, test error 49.47
# Epoch   200, train loss 0.918723, train error 30.25,  test loss 1.538486, test error 51.40
# Epoch   300, train loss 0.838693, train error 28.25,  test loss 1.754058, test error 52.80
# Epoch   400, train loss 0.786520, train error 26.47,  test loss 1.939727, test error 55.33
# Epoch   500, train loss 0.767005, train error 26.28,  test loss 2.068702, test error 55.55
# Epoch   600, train loss 0.720225, train error 24.97,  test loss 2.196715, test error 55.30
# Epoch   700, train loss 0.724668, train error 25.07,  test loss 2.326184, test error 55.33
# Epoch   800, train loss 0.706089, train error 24.60,  test loss 2.383377, test error 55.62
# Epoch   900, train loss 0.694510, train error 23.40,  test loss 2.493890, test error 55.35
# Training model with  35 hidden variables
# Epoch     0, train loss 2.270902, train error 84.25,  test loss 2.263609, test error 84.38
# Epoch   100, train loss 1.009401, train error 33.30,  test loss 1.405652, test error 49.95
# Epoch   200, train loss 0.777707, train error 25.85,  test loss 1.741762, test error 53.15
# Epoch   300, train loss 0.682066, train error 23.65,  test loss 2.065037, test error 54.03
# Epoch   400, train loss 0.601071, train error 20.38,  test loss 2.394033, test error 55.65
# Epoch   500, train loss 0.558161, train error 19.22,  test loss 2.758558, test error 57.20
# Epoch   600, train loss 0.537004, train error 18.30,  test loss 3.121149, test error 56.70
# Epoch   700, train loss 0.490459, train error 17.03,  test loss 3.372678, test error 56.28
# Epoch   800, train loss 0.443515, train error 15.35,  test loss 3.681568, test error 56.60
# Epoch   900, train loss 0.451263, train error 16.47,  test loss 4.089700, test error 56.60
# Training model with  40 hidden variables
# Epoch     0, train loss 2.058799, train error 77.10,  test loss 1.987657, test error 76.03
# Epoch   100, train loss 0.916042, train error 29.32,  test loss 1.444294, test error 49.92
# Epoch   200, train loss 0.682981, train error 22.55,  test loss 1.889212, test error 53.17
# Epoch   300, train loss 0.523597, train error 16.85,  test loss 2.464442, test error 55.72
# Epoch   400, train loss 0.429346, train error 13.88,  test loss 3.091486, test error 56.10
# Epoch   500, train loss 0.357235, train error 12.32,  test loss 3.835663, test error 57.62
# Epoch   600, train loss 0.324404, train error 11.10,  test loss 4.481174, test error 56.75
# Epoch   700, train loss 0.278807, train error 9.60,  test loss 5.152648, test error 57.72
# Epoch   800, train loss 0.292598, train error 10.47,  test loss 5.597860, test error 56.75
# Epoch   900, train loss 0.277394, train error 9.80,  test loss 6.364539, test error 57.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.082744, train error 77.28,  test loss 2.025022, test error 75.22
# Epoch   100, train loss 0.808665, train error 25.28,  test loss 1.472613, test error 48.72
# Epoch   200, train loss 0.498262, train error 15.72,  test loss 2.229535, test error 53.00
# Epoch   300, train loss 0.321953, train error 10.07,  test loss 3.262469, test error 55.08
# Epoch   400, train loss 0.197011, train error 5.85,  test loss 4.454489, test error 55.85
# Epoch   500, train loss 0.139602, train error 4.03,  test loss 5.866674, test error 56.38
# Epoch   600, train loss 0.170088, train error 6.10,  test loss 6.958458, test error 56.97
# Epoch   700, train loss 0.013620, train error 0.00,  test loss 8.076137, test error 56.92
# Epoch   800, train loss 0.008929, train error 0.00,  test loss 8.773352, test error 57.15
# Epoch   900, train loss 0.006526, train error 0.00,  test loss 9.288520, test error 57.22
# Training model with  50 hidden variables
# Epoch     0, train loss 2.084212, train error 77.97,  test loss 2.038597, test error 77.57
# Epoch   100, train loss 0.722332, train error 22.55,  test loss 1.685625, test error 52.42
# Epoch   200, train loss 0.318271, train error 8.93,  test loss 2.919027, test error 55.90
# Epoch   300, train loss 0.137619, train error 3.22,  test loss 4.725519, test error 57.35
# Epoch   400, train loss 0.025508, train error 0.00,  test loss 6.297997, test error 57.25
# Epoch   500, train loss 0.012521, train error 0.00,  test loss 7.241994, test error 57.47
# Epoch   600, train loss 0.008176, train error 0.00,  test loss 7.878793, test error 57.80
# Epoch   700, train loss 0.005906, train error 0.00,  test loss 8.376072, test error 57.85
# Epoch   800, train loss 0.004574, train error 0.00,  test loss 8.765032, test error 57.97
# Epoch   900, train loss 0.003709, train error 0.00,  test loss 9.088529, test error 57.95
# Training model with  55 hidden variables
# Epoch     0, train loss 2.115665, train error 77.78,  test loss 2.072428, test error 77.12
# Epoch   100, train loss 0.650958, train error 20.60,  test loss 1.663490, test error 52.05
# Epoch   200, train loss 0.213037, train error 5.30,  test loss 3.084791, test error 54.58
# Epoch   300, train loss 0.038995, train error 0.00,  test loss 4.933217, test error 55.78
# Epoch   400, train loss 0.014110, train error 0.00,  test loss 6.037786, test error 56.08
# Epoch   500, train loss 0.008325, train error 0.00,  test loss 6.713840, test error 56.22
# Epoch   600, train loss 0.005688, train error 0.00,  test loss 7.182271, test error 56.35
# Epoch   700, train loss 0.004232, train error 0.00,  test loss 7.546971, test error 56.50
# Epoch   800, train loss 0.003363, train error 0.00,  test loss 7.844149, test error 56.42
# Epoch   900, train loss 0.002760, train error 0.00,  test loss 8.105583, test error 56.42
# Training model with  60 hidden variables
# Epoch     0, train loss 2.044948, train error 76.65,  test loss 1.997550, test error 76.88
# Epoch   100, train loss 0.536710, train error 15.38,  test loss 1.744302, test error 49.92
# Epoch   200, train loss 0.114876, train error 1.32,  test loss 3.466238, test error 54.50
# Epoch   300, train loss 0.020058, train error 0.00,  test loss 4.850275, test error 54.80
# Epoch   400, train loss 0.009638, train error 0.00,  test loss 5.578959, test error 54.95
# Epoch   500, train loss 0.006069, train error 0.00,  test loss 6.030821, test error 54.58
# Epoch   600, train loss 0.004304, train error 0.00,  test loss 6.375467, test error 54.67
# Epoch   700, train loss 0.003308, train error 0.00,  test loss 6.643343, test error 54.58
# Epoch   800, train loss 0.002642, train error 0.00,  test loss 6.865840, test error 54.53
# Epoch   900, train loss 0.002193, train error 0.00,  test loss 7.057706, test error 54.58
# Training model with  70 hidden variables
# Epoch     0, train loss 2.033103, train error 74.60,  test loss 1.970057, test error 75.35
# Epoch   100, train loss 0.336368, train error 8.85,  test loss 1.891247, test error 50.62
# Epoch   200, train loss 0.028531, train error 0.00,  test loss 3.450666, test error 52.17
# Epoch   300, train loss 0.010030, train error 0.00,  test loss 4.156822, test error 52.08
# Epoch   400, train loss 0.005700, train error 0.00,  test loss 4.567014, test error 52.22
# Epoch   500, train loss 0.003884, train error 0.00,  test loss 4.848158, test error 52.22
# Epoch   600, train loss 0.002882, train error 0.00,  test loss 5.065593, test error 52.20
# Epoch   700, train loss 0.002271, train error 0.00,  test loss 5.244377, test error 52.33
# Epoch   800, train loss 0.001856, train error 0.00,  test loss 5.389451, test error 52.33
# Epoch   900, train loss 0.001566, train error 0.00,  test loss 5.519006, test error 52.33
# Training model with  80 hidden variables
# Epoch     0, train loss 2.014312, train error 73.45,  test loss 1.976303, test error 74.50
# Epoch   100, train loss 0.222739, train error 3.45,  test loss 2.035612, test error 50.83
# Epoch   200, train loss 0.020529, train error 0.00,  test loss 3.316271, test error 51.70
# Epoch   300, train loss 0.008283, train error 0.00,  test loss 3.879053, test error 51.83
# Epoch   400, train loss 0.004842, train error 0.00,  test loss 4.206134, test error 52.28
# Epoch   500, train loss 0.003322, train error 0.00,  test loss 4.434777, test error 52.03
# Epoch   600, train loss 0.002497, train error 0.00,  test loss 4.616570, test error 52.08
# Epoch   700, train loss 0.001976, train error 0.00,  test loss 4.760724, test error 52.35
# Epoch   800, train loss 0.001625, train error 0.00,  test loss 4.884832, test error 52.35
# Epoch   900, train loss 0.001373, train error 0.00,  test loss 4.990178, test error 52.33
# Training model with  90 hidden variables
# Epoch     0, train loss 2.018014, train error 74.93,  test loss 1.934016, test error 74.57
# Epoch   100, train loss 0.140959, train error 1.03,  test loss 2.142217, test error 51.42
# Epoch   200, train loss 0.014937, train error 0.00,  test loss 3.182773, test error 52.60
# Epoch   300, train loss 0.006611, train error 0.00,  test loss 3.608956, test error 52.72
# Epoch   400, train loss 0.004024, train error 0.00,  test loss 3.868607, test error 52.92
# Epoch   500, train loss 0.002833, train error 0.00,  test loss 4.057056, test error 53.20
# Epoch   600, train loss 0.002158, train error 0.00,  test loss 4.201199, test error 53.08
# Epoch   700, train loss 0.001726, train error 0.00,  test loss 4.322306, test error 53.08
# Epoch   800, train loss 0.001429, train error 0.00,  test loss 4.423923, test error 52.95
# Epoch   900, train loss 0.001214, train error 0.00,  test loss 4.512885, test error 53.00
# Training model with 100 hidden variables
# Epoch     0, train loss 2.003566, train error 73.62,  test loss 1.940811, test error 74.00
# Epoch   100, train loss 0.101826, train error 0.30,  test loss 2.147317, test error 50.55
# Epoch   200, train loss 0.012543, train error 0.00,  test loss 3.013109, test error 50.65
# Epoch   300, train loss 0.005754, train error 0.00,  test loss 3.368329, test error 50.67
# Epoch   400, train loss 0.003576, train error 0.00,  test loss 3.596521, test error 50.65
# Epoch   500, train loss 0.002536, train error 0.00,  test loss 3.759377, test error 50.58
# Epoch   600, train loss 0.001941, train error 0.00,  test loss 3.887135, test error 50.60
# Epoch   700, train loss 0.001560, train error 0.00,  test loss 3.992961, test error 50.62
# Epoch   800, train loss 0.001294, train error 0.00,  test loss 4.083532, test error 50.65
# Epoch   900, train loss 0.001102, train error 0.00,  test loss 4.160709, test error 50.70
# Training model with 120 hidden variables
# Epoch     0, train loss 1.995040, train error 74.12,  test loss 1.930891, test error 75.00
# Epoch   100, train loss 0.048824, train error 0.00,  test loss 2.183052, test error 49.55
# Epoch   200, train loss 0.009339, train error 0.00,  test loss 2.775954, test error 49.53
# Epoch   300, train loss 0.004645, train error 0.00,  test loss 3.043185, test error 49.53
# Epoch   400, train loss 0.002970, train error 0.00,  test loss 3.219253, test error 49.47
# Epoch   500, train loss 0.002139, train error 0.00,  test loss 3.347718, test error 49.45
# Epoch   600, train loss 0.001654, train error 0.00,  test loss 3.449237, test error 49.58
# Epoch   700, train loss 0.001337, train error 0.00,  test loss 3.532774, test error 49.47
# Epoch   800, train loss 0.001116, train error 0.00,  test loss 3.603921, test error 49.55
# Epoch   900, train loss 0.000954, train error 0.00,  test loss 3.666555, test error 49.75
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952001, train error 71.88,  test loss 1.896141, test error 73.40
# Epoch   100, train loss 0.034658, train error 0.00,  test loss 2.138945, test error 49.50
# Epoch   200, train loss 0.007904, train error 0.00,  test loss 2.605607, test error 49.58
# Epoch   300, train loss 0.004084, train error 0.00,  test loss 2.828522, test error 49.50
# Epoch   400, train loss 0.002667, train error 0.00,  test loss 2.974750, test error 49.53
# Epoch   500, train loss 0.001944, train error 0.00,  test loss 3.084111, test error 49.35
# Epoch   600, train loss 0.001512, train error 0.00,  test loss 3.171179, test error 49.38
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.243378, test error 49.40
# Epoch   800, train loss 0.001030, train error 0.00,  test loss 3.305165, test error 49.45
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.359098, test error 49.47
# Training model with 160 hidden variables
# Epoch     0, train loss 1.935723, train error 71.70,  test loss 1.881504, test error 73.60
# Epoch   100, train loss 0.028595, train error 0.00,  test loss 2.189695, test error 50.17
# Epoch   200, train loss 0.007202, train error 0.00,  test loss 2.611819, test error 50.17
# Epoch   300, train loss 0.003781, train error 0.00,  test loss 2.815027, test error 50.03
# Epoch   400, train loss 0.002484, train error 0.00,  test loss 2.951046, test error 49.90
# Epoch   500, train loss 0.001819, train error 0.00,  test loss 3.052675, test error 49.90
# Epoch   600, train loss 0.001420, train error 0.00,  test loss 3.135111, test error 49.85
# Epoch   700, train loss 0.001156, train error 0.00,  test loss 3.202188, test error 49.85
# Epoch   800, train loss 0.000971, train error 0.00,  test loss 3.259782, test error 49.88
# Epoch   900, train loss 0.000833, train error 0.00,  test loss 3.310170, test error 49.83
# Training model with 180 hidden variables
# Epoch     0, train loss 1.945178, train error 71.75,  test loss 1.869754, test error 71.78
# Epoch   100, train loss 0.022789, train error 0.00,  test loss 2.113004, test error 49.67
# Epoch   200, train loss 0.006336, train error 0.00,  test loss 2.463726, test error 49.70
# Epoch   300, train loss 0.003395, train error 0.00,  test loss 2.641585, test error 49.60
# Epoch   400, train loss 0.002261, train error 0.00,  test loss 2.760613, test error 49.62
# Epoch   500, train loss 0.001668, train error 0.00,  test loss 2.850450, test error 49.67
# Epoch   600, train loss 0.001308, train error 0.00,  test loss 2.921856, test error 49.67
# Epoch   700, train loss 0.001070, train error 0.00,  test loss 2.982007, test error 49.67
# Epoch   800, train loss 0.000900, train error 0.00,  test loss 3.033413, test error 49.65
# Epoch   900, train loss 0.000775, train error 0.00,  test loss 3.078475, test error 49.70
# Training model with 200 hidden variables
# Epoch     0, train loss 1.888810, train error 69.45,  test loss 1.843108, test error 72.45
# Epoch   100, train loss 0.020521, train error 0.00,  test loss 2.100078, test error 48.38
# Epoch   200, train loss 0.005997, train error 0.00,  test loss 2.422887, test error 47.88
# Epoch   300, train loss 0.003271, train error 0.00,  test loss 2.592433, test error 48.08
# Epoch   400, train loss 0.002188, train error 0.00,  test loss 2.707601, test error 48.22
# Epoch   500, train loss 0.001619, train error 0.00,  test loss 2.793436, test error 48.35
# Epoch   600, train loss 0.001273, train error 0.00,  test loss 2.861949, test error 48.50
# Epoch   700, train loss 0.001042, train error 0.00,  test loss 2.919246, test error 48.45
# Epoch   800, train loss 0.000878, train error 0.00,  test loss 2.968629, test error 48.53
# Epoch   900, train loss 0.000756, train error 0.00,  test loss 3.012048, test error 48.55
# Training model with 250 hidden variables
# Epoch     0, train loss 1.890957, train error 69.50,  test loss 1.829351, test error 72.05
# Epoch   100, train loss 0.017026, train error 0.00,  test loss 1.940484, test error 47.12
# Epoch   200, train loss 0.005314, train error 0.00,  test loss 2.193179, test error 47.22
# Epoch   300, train loss 0.002953, train error 0.00,  test loss 2.325200, test error 47.22
# Epoch   400, train loss 0.001994, train error 0.00,  test loss 2.416244, test error 47.12
# Epoch   500, train loss 0.001484, train error 0.00,  test loss 2.484703, test error 47.17
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.539567, test error 47.15
# Epoch   700, train loss 0.000962, train error 0.00,  test loss 2.585927, test error 47.22
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.626075, test error 47.22
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.661251, test error 47.22
# Training model with 300 hidden variables
# Epoch     0, train loss 1.879147, train error 68.32,  test loss 1.800460, test error 70.75
# Epoch   100, train loss 0.014188, train error 0.00,  test loss 1.856400, test error 46.45
# Epoch   200, train loss 0.004759, train error 0.00,  test loss 2.076324, test error 46.60
# Epoch   300, train loss 0.002697, train error 0.00,  test loss 2.193751, test error 46.72
# Epoch   400, train loss 0.001838, train error 0.00,  test loss 2.275255, test error 46.78
# Epoch   500, train loss 0.001375, train error 0.00,  test loss 2.337495, test error 46.70
# Epoch   600, train loss 0.001090, train error 0.00,  test loss 2.388065, test error 46.65
# Epoch   700, train loss 0.000897, train error 0.00,  test loss 2.430512, test error 46.65
# Epoch   800, train loss 0.000759, train error 0.00,  test loss 2.467007, test error 46.60
# Epoch   900, train loss 0.000656, train error 0.00,  test loss 2.499091, test error 46.60
# Training model with 400 hidden variables
# Epoch     0, train loss 1.863171, train error 66.93,  test loss 1.789128, test error 68.65
# Epoch   100, train loss 0.011527, train error 0.00,  test loss 1.697158, test error 45.22
# Epoch   200, train loss 0.004128, train error 0.00,  test loss 1.857958, test error 44.90
# Epoch   300, train loss 0.002395, train error 0.00,  test loss 1.949534, test error 44.92
# Epoch   400, train loss 0.001650, train error 0.00,  test loss 2.012601, test error 44.83
# Epoch   500, train loss 0.001243, train error 0.00,  test loss 2.060880, test error 44.95
# Epoch   600, train loss 0.000990, train error 0.00,  test loss 2.099939, test error 44.80
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.133404, test error 44.80
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.161996, test error 44.80
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.187278, test error 44.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
